# %%
import pandas as pd

df = pd.read_csv("in_combined.csv")

columns = ["pm10 std", "pm25 std", "pm100 std", "pm10 env", "pm24 env", "pm100 env", "Time", "Temperature", "Gas", "Humidity", "Pressure", "Altitude"]

means = df[columns].mean()

print(means)
# Out:
# pm10 std            0.000000
# pm25 std            0.060000
# pm100 std           0.060000
# pm10 env            0.000000
# pm24 env            0.060000
# pm100 env           0.060000
# Time               22.440262
# Temperature    664442.136667
# Gas                36.613883
# Humidity         1001.667768
# Pressure           99.159515
# Altitude                 NaN
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv("in_combined.csv")

columns = ["pm10 std", "pm25 std", "pm100 std", "pm10 env", "pm24 env", "pm100 env", "Time", "Temperature", "Gas", "Humidity", "Pressure", "Altitude"]

std_devs = df[columns].std()

print(std_devs)
# Out:
# pm10 std            0.000000
# pm25 std            0.237884
# pm100 std           0.237884
# pm10 env            0.000000
# pm24 env            0.237884
# pm100 env           0.237884
# Time                0.669299
# Temperature    309624.032964
# Gas                 3.749057
# Humidity           22.546837
# Pressure          228.867355
# Altitude                 NaN
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv("combined.csv")

columns = ["pm10 std", "pm25 std", "pm100 std", "pm10 env", "pm24 env", "pm100 env", "Time", "Temperature", "Gas", "Humidity", "Pressure", "Altitude"]

means = df[columns].mean()

print(means)
# Out:
# pm10 std            0.186667
# pm25 std            0.666667
# pm100 std           0.743333
# pm10 env            0.186667
# pm24 env            0.666667
# pm100 env           0.743333
# Time               18.509951
# Temperature    563616.476667
# Gas                39.232621
# Humidity         1001.315783
# Pressure          102.114882
# Altitude                 NaN
# dtype: float64

# %%
import pandas as pd

df = pd.read_csv("combined.csv")

columns = ["pm10 std", "pm25 std", "pm100 std", "pm10 env", "pm24 env", "pm100 env", "Time", "Temperature", "Gas", "Humidity", "Pressure", "Altitude"]

std_devs = df[columns].std()

print(std_devs)
# Out:
# pm10 std            0.438707
# pm25 std            1.267904
# pm100 std           1.593503
# pm10 env            0.438707
# pm24 env            1.267904
# pm100 env           1.593503
# Time                3.361773
# Temperature    158650.640287
# Gas                 5.781142
# Humidity           22.527301
# Pressure          228.702084
# Altitude                 NaN
# dtype: float64
